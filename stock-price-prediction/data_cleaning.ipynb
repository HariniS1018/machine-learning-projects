# %% [markdown]
# **1. Import Necessary Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **2. To read the data into Python.**

# %%
df = pd.read_csv('nifty_ds.csv')
df.head()
# Out:
#          Date      Open      High       Low     Close   Shares Traded   \
# 0  12-AUG-2024  24320.05  24472.80  24212.10  24347.00       279925100
# 1  13-AUG-2024  24342.35  24359.95  24116.50  24139.00       239727640
# 2  14-AUG-2024  24184.40  24196.50  24099.70  24143.75       303254705
# 3  16-AUG-2024  24334.85  24563.90  24204.50  24541.15       271611087
# 4  19-AUG-2024  24636.35  24638.80  24522.95  24572.65       243645503
#
#    Turnover (₹ Cr)
# 0         30311.85
# 1         25459.58
# 2         27834.61
# 3         28521.90
# 4         22124.41

# %% [markdown]
# **3. Check For any missing Values**

# %%
print(df.isnull().sum())
# Out:
# Date               0
# Open               0
# High               0
# Low                0
# Close              0
# Shares Traded      0
# Turnover (₹ Cr)    0
# dtype: int64

# %% [markdown]
# **4. Check for any duplicate entries**

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# **5. Dealing with Inconsistent Data**

# %%
numerical_cols = df.select_dtypes(include=np.number).columns
print(numerical_cols)

for col in numerical_cols:
    invalid = df[df[col] < 0]

    if not invalid.empty:
        print(f"Invalid (negative) values found in '{col}':\n", invalid)
        print("-" * 30)
# Out:
# Index(['Open ', 'High ', 'Low ', 'Close ', 'Shares Traded ',
#        'Turnover (₹ Cr)'],
#       dtype='object')

# %% [markdown]
# **6. Stripping trailing spaces in column names**

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Shares Traded',
#        'Turnover (₹ Cr)'],
#       dtype='object')

# %% [markdown]
# **7. Check for Data Types**

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             249 non-null    object
#  1   Open             249 non-null    float64
#  2   High             249 non-null    float64
#  3   Low              249 non-null    float64
#  4   Close            249 non-null    float64
#  5   Shares Traded    249 non-null    int64
#  6   Turnover (₹ Cr)  249 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.7+ KB
# None

# %% [markdown]
# **8. Convert Date to Approriate Date type**

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%b-%Y')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             249 non-null    datetime64[ns]
#  1   Open             249 non-null    float64
#  2   High             249 non-null    float64
#  3   Low              249 non-null    float64
#  4   Close            249 non-null    float64
#  5   Shares Traded    249 non-null    int64
#  6   Turnover (₹ Cr)  249 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.7 KB
# None

# %%
df = df.rename ({'Turnover (₹ Cr)': 'Turnover (Cr Rs)'}, axis =1)
df.head()
# Out:
#         Date      Open      High       Low     Close  Shares Traded  \
# 0 2024-08-12  24320.05  24472.80  24212.10  24347.00      279925100
# 1 2024-08-13  24342.35  24359.95  24116.50  24139.00      239727640
# 2 2024-08-14  24184.40  24196.50  24099.70  24143.75      303254705
# 3 2024-08-16  24334.85  24563.90  24204.50  24541.15      271611087
# 4 2024-08-19  24636.35  24638.80  24522.95  24572.65      243645503
#
#    Turnover (Cr Rs)
# 0          30311.85
# 1          25459.58
# 2          27834.61
# 3          28521.90
# 4          22124.41

# %% [markdown]
# **9. Save Cleaned Data**

# %%
df.to_csv('cleaned_nifty_ds.csv', index=False)

# %% [markdown]
# **Conclusion:**
#
# - No missing values.
# - No duplicate records.
# - No negative values in any attributes.
# - Removed Trailing spaces in column names.
# - Renamed Columns.
# - Set appropriate Data types for all attributes.
# - saved the cleaned data.
